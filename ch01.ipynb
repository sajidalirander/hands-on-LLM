# %% [markdown]
# Chapter Summary: An Introduction to Large Language Models
# 1. Bag of words
# 2. Neural network
# 3. Attention mechanism -- encoder and decoder
# 4. Representation models -- encoder only (e.g., BERT)
# 5. Generative models -- decoder only (e.g., GPT family)

# %%
import os
print(os.getenv("HF_HOME"))  # Check if HF_HOME is set
# Out:
# None

# %%
# !ls -lh /root/.cache/huggingface/hub
# Out:
# total 8.0K
# drwxr-xr-x 6 root root 4.0K Feb 25 09:14 models--microsoft--Phi-3-mini-4k-instruct
# -rw-r--r-- 1 root root    1 Feb 25 09:10 version.txt

# %%
# !ls -lha /root/
# Out:
# total 72K
# drwx------ 1 root root 4.0K Feb 25 08:55 .
# drwxr-xr-x 1 root root 4.0K Feb 25 08:50 ..
# -r-xr-xr-x 1 root root 1.2K Jan  1  2000 .bashrc
# drwxr-xr-x 1 root root 4.0K Feb 25 09:10 .cache
# drwxr-xr-x 1 root root 4.0K Feb 25 08:51 .config
# drwxr-xr-x 5 root root 4.0K Feb 21 14:31 .ipython
# drwx------ 1 root root 4.0K Feb 21 14:31 .jupyter
# drwxr-xr-x 2 root root 4.0K Feb 25 08:50 .keras
# drwx------ 3 root root 4.0K Feb 21 14:12 .launchpadlib
# drwxr-xr-x 1 root root 4.0K Feb 21 14:31 .local
# drwxr-xr-x 4 root root 4.0K Feb 21 14:31 .npm
# drwx------ 3 root root 4.0K Feb 25 08:55 .nv
# -rw-r--r-- 1 root root  161 Jul  9  2019 .profile
# -r-xr-xr-x 1 root root  254 Jan  1  2000 .tmux.conf
# -rw-r--r-- 1 root root  211 Feb 21 14:31 .wget-hsts

# %%
import os
os.environ["HF_HOME"] = "/content/drive/MyDrive/LLM/"

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3-mini-4k-instruct",
                                             device_map = "cuda",
                                             torch_dtype = "auto",
                                             trust_remote_code = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline

pipe = pipeline("text-generation",
                model = model,
                tokenizer = tokenizer,
                return_full_text = False,
                max_new_tokens = 1000,
                do_sample = False)
# Out:
# Device set to use cuda

# %%
msg = [{"role": "user", "content": "Tell me something about Sajid Ali."}]
output = pipe(msg)
print(output[0]["generated_text"])
# Out:
#  Sajid Ali is a renowned Indian playback singer, composer, and music director, primarily known for his work in the Hindi film industry. Born on August 1, 1972, in Mumbai, India, he comes from a family with a rich musical background. His father, Ghulam Ali, was a famous ghazal singer, and his grandfather, Ghulam Rasool, was a well-known music director.
#
# Sajid Ali started his career as a playback singer in the early 1990s. He has sung for numerous Bollywood films, including "Dil Se.." (1998), "Kuch Kuch Hota Hai" (1998), "Kabhi Khushi Kabhie Gham" (2001), "Kal Ho Naa Ho" (2003), "Dhoom 2" (2006), and "Raanjhanaa" (2013). He has also lent his voice to many popular songs in the Indian music industry, such as "Tujhe Dekha To" from "Kuch Kuch Hota Hai," "Kabhi Kabhi" from "Kabhi Khushi Kabhie Gham," and "Kabhi Kabhi" from "Kal Ho Naa Ho."
#
# ...

# %%
# !pwd
# Out:
# /content
